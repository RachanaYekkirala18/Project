# %% [markdown]
# # Project: 120 years of Olympic Data

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('athlete_events.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# # Understanding Data

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.nunique()
# Out:
# ID        135571
# Name      134732
# Sex            2
# Age           74
# Height        95
# Weight       220
# Team        1184
# NOC          230
# Games         51
# Year          35
# Season         2
# City          42
# Sport         66
# Event        765
# Medal          3
# dtype: int64

# %% [markdown]
# # Missing Data

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
plt.subplots(figsize= (15,5))
sns.heatmap(df.isnull(), cbar= False, cmap= "Oranges")
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (269731, 15)

# %%
df = df.drop(["ID","Games"], axis=1)
df
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
#         NOC  Year  Season            City          Sport  \
# ...

# %% [markdown]
# # Data Filling

# %%
df['Medal'] = df['Medal'].fillna(value='No Medal')

# %%
avg = np.round(np.mean(df['Age']),1)
df['Age'] = df['Age'].fillna(avg)

# %%
import numpy as np
imp_col = ['Height','Weight']
for col in imp_col:
    df[col] = df[col].fillna(np.mean(df[col]))
    df[col] = np.round(df[col],1)
# df['Weight']=df['Weight'].fillna(df['Weight'].m().iloc[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269731 entries, 0 to 271115
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    269731 non-null  object
#  1   Sex     269731 non-null  object
#  2   Age     269731 non-null  float64
#  3   Height  269731 non-null  float64
#  4   Weight  269731 non-null  float64
#  5   Team    269731 non-null  object
#  6   NOC     269731 non-null  object
#  7   Year    269731 non-null  int64
#  8   Season  269731 non-null  object
#  9   City    269731 non-null  object
#  10  Sport   269731 non-null  object
#  11  Event   269731 non-null  object
#  12  Medal   269731 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 28.8+ MB

# %%
df.shape
# Out:
# (269731, 13)

# %%
male = df[df['Sex'] == 'M']
female = df[df['Sex'] == 'F']

plt.figure(figsize=(9,5))
plt.scatter(male.Height,male.Weight,alpha=0.4,label = "male",color="orange") #alpha->transparency
plt.scatter(female.Height,female.Weight,alpha=0.4,label="female",color="yellow")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height and weight comparison by gender")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.countplot(df['Age'], color='r')
plt.xticks(rotation = 90)
plt.title('Distribution of olympic athletes by Age', fontsize = 20)
plt.show()

# %% [markdown]
# # Sanity check

# %%
df['Age'].max()
# Out:
# 97.0

# %%
df['Age'].min()
# Out:
# 10.0

# %%
plt.hist(df['Age'],color='y')

plt.title("Hist for Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#Sanity check for year it should not be negative
if (df['Year'].max() <= 2016 and df['Year'].min() >= 1896):
    print(df['Year'].describe(), "\n")
    print("Sanity check for Year done. No outliers")
else:
    print("Outliers found")
# Out:
# count    269731.000000
# mean       1978.623073
# std          29.752055
# min        1896.000000
# 25%        1960.000000
# 50%        1988.000000
# 75%        2002.000000
# max        2016.000000
# Name: Year, dtype: float64
#
# Sanity check for Year done. No outliers

# %%
#sanity check for height
if (df['Height'].min()>=100):
    print(df['Height'].describe(), "\n")
    print("No outliers after sanity check")
else:
    print("Outliers found")
# Out:
# count    269731.000000
# mean        175.330460
# std           9.301327
# min         127.000000
# 25%         170.000000
# 50%         175.300000
# 75%         180.000000
# max         226.000000
# Name: Height, dtype: float64
#
# No outliers after sanity check

# %%
#sanity check for weight
if (df['Weight'].min()>=20):
    print(df['Height'].describe(), "\n")
    print("No outliers found after sanity check")
else:
    print("Outliers found")
# Out:
# count    269731.000000
# mean        175.330460
# std           9.301327
# min         127.000000
# 25%         170.000000
# 50%         175.300000
# 75%         180.000000
# max         226.000000
# Name: Height, dtype: float64
#
# No outliers found after sanity check

# %%
allAthletesHW = df[(df['Height'].notnull()) & (df['Weight'].notnull())]

# %%
allAthletesHW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269731 entries, 0 to 271115
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    269731 non-null  object
#  1   Sex     269731 non-null  object
#  2   Age     269731 non-null  float64
#  3   Height  269731 non-null  float64
#  4   Weight  269731 non-null  float64
#  5   Team    269731 non-null  object
#  6   NOC     269731 non-null  object
#  7   Year    269731 non-null  int64
#  8   Season  269731 non-null  object
#  9   City    269731 non-null  object
#  10  Sport   269731 non-null  object
#  11  Event   269731 non-null  object
#  12  Medal   269731 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 28.8+ MB

# %% [markdown]
# #
# The mean Height is 175.35 cm, while the median weight is 70.67 kg.
# The median Height is 175 kg, while the median Weight is 70 kg.
#
# First, I use a scatterplot to represent this data. Later, I use boxplots to represent the evolution of these data through Games.

# %%
df['Medal'].value_counts().plot.bar(color='brown')
plt.title("Medals with count")
plt.xlabel("Medal")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Team'].head(200).value_counts().plot.bar(color='g')

plt.title("Team with count")
plt.xlabel("Team")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
shows = df.drop_duplicates()
shows
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0   175.3    70.7         Denmark
# 3           Edgar Lindenau Aabye   M  34.0   175.3    70.7  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
#         NOC  Year  Season            City          Sport  \
# ...

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
data = ['Age','Year']

df[data] = df[data].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269731 entries, 0 to 271115
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    269731 non-null  object
#  1   Sex     269731 non-null  object
#  2   Age     269731 non-null  int32
#  3   Height  269731 non-null  float64
#  4   Weight  269731 non-null  float64
#  5   Team    269731 non-null  object
#  6   NOC     269731 non-null  object
#  7   Year    269731 non-null  int32
#  8   Season  269731 non-null  object
#  9   City    269731 non-null  object
#  10  Sport   269731 non-null  object
#  11  Event   269731 non-null  object
#  12  Medal   269731 non-null  object
# dtypes: float64(2), int32(2), object(9)
# memory usage: 26.8+ MB

# %% [markdown]
# # Univariate Analysis
#
#
# Univariate Veriable Analysis
#
#     Numeric Veriables:
#         age
#         height
#         weight
#         year
#     Categorical Veriables:
#         name
#         gender
#         team
#         noc
#         season
#         city
#         sport
#         event
#         medal

# %%
def plotHistogram(variable):
    plt.figure()
    plt.hist(df[variable],bins=85,color="purple")
    plt.xlabel(variable.upper())
    plt.ylabel("Frequency")
    plt.title(f"Data Frequency - {variable}")
    plt.show

# %%
category = ['Age','Height','Weight','Year']
for c in category:
    plotHistogram(c)

# %%
category = ['Age','Height','Weight','Year']
def plotBoxGraph(veriable):
  
    plt.boxplot(df[veriable])
    plt.title(f"Box plot for {veriable} veriable")
    plt.xlabel(veriable)
    plt.ylabel('Value')
    plt.show()

for c in category:

    plotBoxGraph(c)

# %% [markdown]
# # categorical variables

# %%
def plotBar(veriable,n=5):
  
    varValue = df[veriable].value_counts()
    varValue = varValue[:5]
    
    #visualize
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue,color="pink")
    plt.xticks(rotation=45)
    plt.ylabel('Frequency')
    plt.title(veriable)
    plt.show()

# %%
categorical = ['Sex','Team','City']
for c in categorical:
    plotBar(c)

# %% [markdown]
# # bivariate analysis

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', hue='Sex',data=df)
plt.title('Male & Female athlets per year', fontsize = 20)
plt.show()

# %%
M = df[df['Sex'] == 'M']
F = df[df.Sex == "F"]
plt.figure(figsize=(9,5))
plt.scatter(M.Height,M.Weight,alpha=0.4,label = "male",color="blue") #alpha->transparency
plt.scatter(F.Height,F.Weight,alpha=0.4,label="female",color="pink")
plt.xlabel("Height")
plt.ylabel("Weigth")
plt.title("Height and weight comparison by gender")
plt.legend()
plt.show()

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(figsize=(10, 5),color="purple")
plt.title("Medals won in each sport")
# Out:
# Text(0.5, 1.0, 'Medals won in each sport')

# %% [markdown]
# # Multi Varient Analysis

# %%
df_pivot = df.pivot_table(index="Medal",columns="Sex",values=["Height","Weight","Age"],aggfunc={"Height":np.mean,"Weight":np.mean,"Age":[min,max,np.mean,np.std]})
df_pivot
# Out:
#          Age                                                        \
#          max           mean            min           std
# Sex        F   M          F          M   F   M         F         M
# Medal
# Bronze    69  72  24.709361  26.315729  12  10  5.329102  5.873278
# Gold      63  64  24.373098  26.480877  13  13  5.219537  5.989753
# No Medal  74  97  23.561220  26.038230  11  11  5.738872  6.076962
# Silver    55  73  24.445783  26.576550  11  13  5.252968  6.090969
#
#               Height                 Weight
#                 mean                   mean
# Sex                F           M          F          M
# Medal
# Bronze    170.582339  179.342892  63.629541  76.483662
# Gold      171.007339  179.817761  64.062183  76.997610
# No Medal  168.138036  177.639286  60.631227  73.951381
# Silver    170.833199  179.421028  63.764311  76.597877

# %%
sns.pairplot(df)

# %% [markdown]
# # Analysis Report
# * average age of participants lies around 25 years, maximum age being 97 and minimum 10 years
# * Here in the dataset we have oylmpic games starting from year 1896 to 2016
# * from 2000 olympics happen frequently compared to previous years.
# * the average height and weight of men is more compared to women.
# * USA won most of the gold medals
# * Female participation is increased gradually over the years
